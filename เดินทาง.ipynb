# %% [markdown]
# <a href="https://colab.research.google.com/github/Patsee/data_viz/blob/main/%E0%B9%80%E0%B8%94%E0%B8%B4%E0%B8%99%E0%B8%97%E0%B8%B2%E0%B8%87.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os 
path = '/content/drive/My Drive/Dataviz_Final'

# %%
data_path = os.path.join(path,'passenger-covid19.xlsx')

# %%
data = pd.read_excel(data_path,sheet_name= "Data63-64")
data
# Out:
#    ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-04-25 00:00:00 2021-04-26 00:00:00
# 0      ขนคน (คน)          ทางบก  ...             27472.0             27701.0
# 1      ขนคน (คน)          ทางบก  ...                 NaN                 NaN
# 2      ขนคน (คน)          ทางบก  ...              6163.0              7849.0
# 3     ขนคน (คัน)          ทางบก  ...            800769.0            794328.0
# 4     ขนคน (คัน)          ทางบก  ...            900413.0            920383.0
# 5     ขนคน (คัน)          ทางบก  ...            678044.0           1041714.0
# 6     ขนคน (คัน)          ทางบก  ...            697964.0           1096281.0
# 7     ขนคน (คัน)          ทางบก  ...                 NaN                 NaN
# 8      ขนคน (คน)          ทางบก  ...              1996.0              3977.0
# 9      ขนคน (คน)          ทางบก  ...                 NaN                 NaN
# 10     ขนคน (คน)          ทางบก  ...            346305.0            481172.0
# ...

# %%
data1 = data.drop([1,2,7,8,9,12,13,14,15,19,29,30,31,32,33,34])
data1
# Out:
#    ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-04-25 00:00:00 2021-04-26 00:00:00
# 0      ขนคน (คน)          ทางบก  ...             27472.0             27701.0
# 3     ขนคน (คัน)          ทางบก  ...            800769.0            794328.0
# 4     ขนคน (คัน)          ทางบก  ...            900413.0            920383.0
# 5     ขนคน (คัน)          ทางบก  ...            678044.0           1041714.0
# 6     ขนคน (คัน)          ทางบก  ...            697964.0           1096281.0
# 10     ขนคน (คน)          ทางบก  ...            346305.0            481172.0
# 11     ขนคน (คน)          ทางบก  ...             29134.0             39544.0
# 16     ขนคน (คน)         ทางน้ำ  ...              1656.0              5106.0
# 17     ขนคน (คน)         ทางน้ำ  ...              2953.0              9216.0
# 18     ขนคน (คน)         ทางน้ำ  ...             38124.0             39269.0
# 20     ขนคน (คน)         ทางราง  ...             13879.0             16250.0
# ...

# %% [markdown]
# รูปแบบการเดินทาง

# %%
from datetime import datetime

# %%
data1.columns = [i.strftime('%Y-%m-%d') if isinstance(i, datetime) else i for i in data1.columns]
data1.head()
# Out:
#   ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-04-25 2021-04-26
# 0     ขนคน (คน)          ทางบก  ...    27472.0    27701.0
# 3    ขนคน (คัน)          ทางบก  ...   800769.0   794328.0
# 4    ขนคน (คัน)          ทางบก  ...   900413.0   920383.0
# 5    ขนคน (คัน)          ทางบก  ...   678044.0  1041714.0
# 6    ขนคน (คัน)          ทางบก  ...   697964.0  1096281.0
#
# [5 rows x 488 columns]

# %%
data1.columns
# Out:
# Index(['ขนคน/ขนสินค้า', 'โหมดการเดินทาง', 'รูปแบบการเดินทาง',
#        'สาธารณะ/ส่วนบุคคล', 'หน่วยงาน', 'ยานพาหนะ/ท่า', '2020-01-01',
#        '2020-01-02', '2020-01-03', '2020-01-04',
#        ...
#        '2021-04-17', '2021-04-18', '2021-04-19', '2021-04-20', '2021-04-21',
#        '2021-04-22', '2021-04-23', '2021-04-24', '2021-04-25', '2021-04-26'],
#       dtype='object', length=488)

# %%
from datetime import datetime
date_format = "%Y-%m-%d"
a = datetime.strptime('2020-01-01', date_format)
b = datetime.strptime('2020-01-31', date_format)
delta = b - a
delta
# Out:
# datetime.timedelta(days=30)

# %%
data_main = data1.iloc[:,:5]
data_main['No.'] = range(data1.shape[0])
data_main.head()
# Out:
#   ขนคน/ขนสินค้า โหมดการเดินทาง  ... หน่วยงาน No.
# 0     ขนคน (คน)          ทางบก  ...     บขส.   0
# 3    ขนคน (คัน)          ทางบก  ...      ทล.   1
# 4    ขนคน (คัน)          ทางบก  ...      ทล.   2
# 5    ขนคน (คัน)          ทางบก  ...     กทพ.   3
# 6    ขนคน (คัน)          ทางบก  ...     กทพ.   4
#
# [5 rows x 6 columns]

# %%
data_m1_2020 = data1.iloc[:,6:37]
data_m1_2020['No.'] = range(data1.shape[0])
data_m1_2020.head()
# Out:
#   2020-01-01  2020-01-02  2020-01-03  ...  2020-01-30  2020-01-31  No.
# 0     233330    252899.0    225731.0  ...    142709.0    160689.0    0
# 3     977347    987340.0    971727.0  ...    917270.0    995977.0    1
# 4    1072314   1082432.0   1115674.0  ...   1041021.0   1135644.0    2
# 5    1333059   1551116.0   1677364.0  ...   1685989.0   1617737.0    3
# 6    1353179   1582864.0   1724755.0  ...   1744235.0   1668317.0    4
#
# [5 rows x 32 columns]

# %%
data_m2_2020 = data1.iloc[:,37:66]
data_m2_2020['No.'] = range(data1.shape[0])
data_m2_2020.head()
# Out:
#    2020-02-01  2020-02-02  2020-02-03  ...  2020-02-28  2020-02-29  No.
# 0    155232.0    163819.0    151378.0  ...    156698.0    150203.0    0
# 3   1011706.0   1024280.0    947972.0  ...    979986.0   1045391.0    1
# 4   1176853.0   1137948.0   1109268.0  ...   1101241.0   1030114.0    2
# 5   1336418.0   1116921.0   1605334.0  ...   1641942.0   1419770.0    3
# 6   1377517.0   1136919.0   1659090.0  ...   1691972.0   1461698.0    4
#
# [5 rows x 30 columns]

# %%
data_m3_2020 = data1.iloc[:,66:97]
data_m3_2020['No.'] = range(data1.shape[0])
data_m3_2020.head()
# Out:
#    2020-03-01  2020-03-02  2020-03-03  ...  2020-03-30  2020-03-31  No.
# 0    167052.0    153629.0    147364.0  ...      3672.0      2945.0    0
# 3   1012361.0    948278.0    902950.0  ...    649567.0    632838.0    1
# 4   1120555.0   1109792.0   1073004.0  ...    783771.0    773116.0    2
# 5   1208652.0   1552746.0   1526868.0  ...    875624.0    886259.0    3
# 6   1229438.0   1602786.0   1580819.0  ...    918742.0    930726.0    4
#
# [5 rows x 32 columns]

# %%
data_m4_2020 = data1.iloc[:,97:127]
data_m4_2020['No.'] = range(data1.shape[0])
data_m4_2020.head()
# Out:
#   2020-04-01  2020-04-02  2020-04-03  ...  2020-04-29  2020-04-30  No.
# 0       2765      2683.0      2446.0  ...      2578.0      3214.0    0
# 3     642859    629466.0    652657.0  ...    680193.0    764535.0    1
# 4     787895    773336.0    796886.0  ...    823481.0    905596.0    2
# 5     868377    846435.0    932884.0  ...   1075539.0   1144112.0    3
# 6     942254    915985.0   1004310.0  ...   1146435.0   1213586.0    4
#
# [5 rows x 31 columns]

# %%
data_m5_2020 = data1.iloc[:,127:158]
data_m5_2020['No.'] = range(data1.shape[0])
data_m5_2020.head()
# Out:
#    2020-05-01  2020-05-02  2020-05-03  ...  2020-05-30  2020-05-31  No.
# 0      6251.0      5532.0      5639.0  ...     16991.0     17286.0    0
# 3    730402.0    729560.0    647426.0  ...    924141.0    902973.0    1
# 4    810400.0    841439.0    726105.0  ...   1071413.0   1005677.0    2
# 5    784181.0    809540.0    662543.0  ...   1155500.0    964327.0    3
# 6    799194.0    837962.0    680409.0  ...   1191385.0    978872.0    4
#
# [5 rows x 32 columns]

# %%
data_m6_2020 = data1.iloc[:,158:188]
data_m6_2020['No.'] = range(data1.shape[0])
data_m6_2020.head()
# Out:
#    2020-06-01  2020-06-02  2020-06-03  ...  2020-06-29  2020-06-30  No.
# 0     21593.0     20366.0     21028.0  ...     54122.0     51340.0    0
# 3    873395.0    861910.0    861644.0  ...    946838.0    906086.0    1
# 4   1024941.0   1024596.0    977376.0  ...   1113074.0   1076410.0    2
# 5   1373431.0   1558414.0   1079727.0  ...   1563112.0   1546398.0    3
# 6   1418608.0   1608461.0   1104490.0  ...   1609051.0   1592941.0    4
#
# [5 rows x 31 columns]

# %%
data_m7_2020 = data1.iloc[:,188:219]
data_m7_2020['No.'] = range(data1.shape[0])
data_m7_2020.head()
# Out:
#    2020-07-01  2020-07-02  2020-07-03  ...  2020-07-30  2020-07-31  No.
# 0     53921.0     67673.0    122207.0  ...     72474.0     78838.0    0
# 3    882344.0    900705.0   1028955.0  ...    915487.0    971692.0    1
# 4   1051246.0   1075238.0   1220792.0  ...   1097241.0   1160078.0    2
# 5   1495377.0   1557504.0   1655771.0  ...   1560968.0   1634379.0    3
# 6   1543380.0   1608055.0   1706545.0  ...   1612413.0   1686262.0    4
#
# [5 rows x 32 columns]

# %%
data_m8_2020 = data1.iloc[:,219:250]
data_m8_2020['No.'] = range(data1.shape[0])
data_m8_2020.head()
# Out:
#    2020-08-01  2020-08-02  2020-08-03  ...  2020-08-30  2020-08-31  No.
# 0     76935.0     83210.0     72296.0  ...     84967.0     73176.0    0
# 3   1001314.0   1004368.0    932217.0  ...   1002243.0    934204.0    1
# 4   1171679.0   1125466.0   1103969.0  ...   1133636.0   1110420.0    2
# 5   1393028.0   1330462.0   1701949.0  ...   1239179.0   1503300.0    3
# 6   1436346.0   1348230.0   1753388.0  ...   1258252.0   1548770.0    4
#
# [5 rows x 32 columns]

# %%
data_m9_2020 = data1.iloc[:,250:280]
data_m9_2020['No.'] = range(data1.shape[0])
data_m9_2020.head()
# Out:
#    2020-09-01  2020-09-02  2020-09-03  ...  2020-09-29  2020-09-30  No.
# 0     69085.0     71168.0    120831.0  ...     69711.0     70820.0    0
# 3    877791.0    893486.0   1033101.0  ...    891353.0    920945.0    1
# 4   1057717.0   1066494.0   1233839.0  ...   1074824.0   1105444.0    2
# 5   1537206.0   1577317.0   1845504.0  ...   1566935.0   1589935.0    3
# 6   1590736.0   1629462.0   1864644.0  ...   1615284.0   1639562.0    4
#
# [5 rows x 31 columns]

# %%
data_m10_2020 = data1.iloc[:,280:311]
data_m10_2020['No.'] = range(data1.shape[0])
data_m10_2020.head()
# Out:
#    2020-10-01  2020-10-02  2020-10-03  ...  2020-10-30  2020-10-31  No.
# 0     73365.0     86850.0     80476.0  ...     92142.0     82117.0    0
# 3    923284.0    994119.0   1013698.0  ...   1013561.0    999488.0    1
# 4   1109161.0   1185493.0   1181901.0  ...   1209888.0   1178698.0    2
# 5   1643963.0   1624333.0   1437314.0  ...   1709768.0   1528457.0    3
# 6   1696223.0   1676930.0   1478516.0  ...   1761715.0   1568829.0    4
#
# [5 rows x 32 columns]

# %%
data_m11_2020 = data1.iloc[:,311:341]
data_m11_2020['No.'] = range(data1.shape[0])
data_m11_2020.head()
# Out:
#    2020-11-01  2020-11-02  2020-11-03  ...  2020-11-29  2020-11-30  No.
# 0     94082.0     84785.0     80195.0  ...     98257.0     86999.0    0
# 3   1027138.0    956746.0    908674.0  ...   1088836.0   1014865.0    1
# 4   1151335.0   1136129.0   1097227.0  ...   1231685.0   1212679.0    2
# 5   1273483.0   1528765.0   1566267.0  ...   2024017.0   1578367.0    3
# 6   1293284.0   1581168.0   1617665.0  ...   2043682.0   1626513.0    4
#
# [5 rows x 31 columns]

# %%
data_m12_2020 = data1.iloc[:,341:372]
data_m12_2020['No.'] = range(data1.shape[0])
data_m12_2020.head()
# Out:
#    2020-12-01  2020-12-02  2020-12-03  ...  2020-12-30  2020-12-31  No.
# 0     81940.0     80035.0     81284.0  ...    100085.0     72071.0    0
# 3    925143.0    917123.0    926659.0  ...    921017.0    759998.0    1
# 4   1125003.0   1119785.0   1134678.0  ...   1020042.0    819534.0    2
# 5   1601418.0   1588973.0   1619134.0  ...   1244692.0    915861.0    3
# 6   1654771.0   1668871.0   1674703.0  ...   1254057.0    921623.0    4
#
# [5 rows x 32 columns]

# %%
data_m1_2021 = data1.iloc[:,372:403]
data_m1_2021['No.'] = range(data1.shape[0])
data_m1_2021.head()
# Out:
#    2021-01-01  2021-01-02  2021-01-03  ...  2021-01-30  2021-01-31  No.
# 0     67985.0     80226.0     90885.0  ...     27211.0     34400.0    0
# 3    703747.0    761244.0    866788.0  ...    844122.0    798764.0    1
# 4    749670.0    827437.0    942511.0  ...   1003690.0    921249.0    2
# 5    851399.0    826114.0    913157.0  ...   1115275.0    918794.0    3
# 6    857396.0    831515.0    919092.0  ...   1153996.0    936470.0    4
#
# [5 rows x 32 columns]

# %%
data_m2_2021 = data1.iloc[:,403:431]
data_m2_2021['No.'] = range(data1.shape[0])
data_m2_2021.head()
# Out:
#    2021-02-01  2021-02-02  2021-02-03  ...  2021-02-27  2021-02-28  No.
# 0     29973.0     31459.0     30907.0  ...     46610.0     66881.0    0
# 3    826038.0    801251.0    804887.0  ...    930239.0    950337.0    1
# 4    989504.0    973939.0    981044.0  ...   1112029.0   1138220.0    2
# 5   1306177.0   1342184.0   1409694.0  ...   1164657.0   1145290.0    3
# 6   1352214.0   1394310.0   1462830.0  ...   1202711.0   1164225.0    4
#
# [5 rows x 29 columns]

# %%
data_m3_2021 = data1.iloc[:,431:462]
data_m3_2021['No.'] = range(data1.shape[0])
data_m3_2021.head()
# Out:
#    2021-03-01  2021-03-02  2021-03-03  ...  2021-03-30  2021-03-31  No.
# 0     51836.0     47481.0     45784.0  ...     52905.0     46689.0    0
# 3    870996.0    830898.0    860586.0  ...    855397.0    864919.0    1
# 4   1114340.0   1058290.0   1061912.0  ...   1039876.0   1055202.0    2
# 5   1482716.0   1493952.0   1528102.0  ...   1731769.0   1600539.0    3
# 6   1531740.0   1547110.0   1582991.0  ...   1786233.0   1651940.0    4
#
# [5 rows x 32 columns]

# %%
data_m4_2021 = data1.iloc[:,462:]
data_m4_2021['No.'] = range(data1.shape[0])
data_m4_2021.head()
# Out:
#    2021-04-01  2021-04-02  2021-04-03  ...  2021-04-25  2021-04-26  No.
# 0     54445.0     70366.0     60124.0  ...     27472.0     27701.0    0
# 3    871853.0    973011.0   1017964.0  ...    800769.0    794328.0    1
# 4   1068128.0   1175500.0   1202510.0  ...    900413.0    920383.0    2
# 5   1606974.0   1666371.0   1430736.0  ...    678044.0   1041714.0    3
# 6   1666434.0   1719604.0   1480385.0  ...    697964.0   1096281.0    4
#
# [5 rows x 27 columns]

# %%
Data_3 = data1.iloc[10:15,:]
Data_3
# Out:
#    ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-04-25 2021-04-26
# 20     ขนคน (คน)         ทางราง  ...    13879.0    16250.0
# 21     ขนคน (คน)         ทางราง  ...    53961.0   115290.0
# 22     ขนคน (คน)         ทางราง  ...     7515.0    17292.0
# 23     ขนคน (คน)         ทางราง  ...     9506.0    18857.0
# 24     ขนคน (คน)         ทางราง  ...   138523.0   251146.0
#
# [5 rows x 488 columns]

# %%
Data_3 = data1.iloc[10:15,6:]
C = Data_3.sum()
C.sum()
# Out:
# 392339189.0

# %%
Data_4 = data1.iloc[15:,6:]
D = Data_4.sum()
D.sum()
# Out:
# 39331396.0

# %%
import pandas as pd
import os
from datetime import datetime as dt

# %%
path = '/content/drive/My Drive/Dataviz_Final'

# %%
data_file_path = os.path.join(path,'covid19cases.csv')
print(data_file_path)
# Out:
# /content/drive/My Drive/Dataviz_Final/covid19cases.csv

# %%
data_covid = pd.read_csv(data_file_path)
data_covid
# Out:
#          No. announce_date  ... province_of_onset district_of_onset
# 0          1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1          2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2          3     22/1/2020  ...            นครปฐม             เมือง
# 3          4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4          5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...      ...           ...  ...               ...               ...
# 57505  57506     26/4/2021  ...               NaN               NaN
# 57506  57507     26/4/2021  ...               NaN               NaN
# 57507  57508     26/4/2021  ...               NaN               NaN
# 57508  57509     26/4/2021  ...               NaN               NaN
# 57509  57510     26/4/2021  ...               NaN               NaN
#
# [57510 rows x 11 columns]

# %%
data_01 = data_covid.fillna(value={'sex':'ไม่ทราบเพศ','announce_date':'ไม่ทราบวันที่','Notified date' : 'ไม่ทราบวันที่', 'age': 31 ,'nationality': 'ไม่ทราบสัญชาติ','province_of_isolation':'ไม่ทราบจังหวัด' , 'province_of_onset':'ไม่ทราบจังหวัด','district_of_onset':'ไม่ทราบอำเภอ'})
data_01
# Out:
#          No. announce_date  ... province_of_onset district_of_onset
# 0          1     12/1/2020  ...     กรุงเทพมหานคร      ไม่ทราบอำเภอ
# 1          2     17/1/2020  ...     กรุงเทพมหานคร      ไม่ทราบอำเภอ
# 2          3     22/1/2020  ...            นครปฐม             เมือง
# 3          4     22/1/2020  ...     กรุงเทพมหานคร      ไม่ทราบอำเภอ
# 4          5     24/1/2020  ...     กรุงเทพมหานคร      ไม่ทราบอำเภอ
# ...      ...           ...  ...               ...               ...
# 57505  57506     26/4/2021  ...    ไม่ทราบจังหวัด      ไม่ทราบอำเภอ
# 57506  57507     26/4/2021  ...    ไม่ทราบจังหวัด      ไม่ทราบอำเภอ
# 57507  57508     26/4/2021  ...    ไม่ทราบจังหวัด      ไม่ทราบอำเภอ
# 57508  57509     26/4/2021  ...    ไม่ทราบจังหวัด      ไม่ทราบอำเภอ
# 57509  57510     26/4/2021  ...    ไม่ทราบจังหวัด      ไม่ทราบอำเภอ
#
# [57510 rows x 11 columns]

# %%
from datetime import time

# %%
data_01['announce_date'] = pd.to_datetime(data_01['announce_date'], format='%d/%m/%Y')
data_01
# Out:
#          No. announce_date  ... province_of_onset district_of_onset
# 0          1    2020-01-12  ...     กรุงเทพมหานคร      ไม่ทราบอำเภอ
# 1          2    2020-01-17  ...     กรุงเทพมหานคร      ไม่ทราบอำเภอ
# 2          3    2020-01-22  ...            นครปฐม             เมือง
# 3          4    2020-01-22  ...     กรุงเทพมหานคร      ไม่ทราบอำเภอ
# 4          5    2020-01-24  ...     กรุงเทพมหานคร      ไม่ทราบอำเภอ
# ...      ...           ...  ...               ...               ...
# 57505  57506    2021-04-26  ...    ไม่ทราบจังหวัด      ไม่ทราบอำเภอ
# 57506  57507    2021-04-26  ...    ไม่ทราบจังหวัด      ไม่ทราบอำเภอ
# 57507  57508    2021-04-26  ...    ไม่ทราบจังหวัด      ไม่ทราบอำเภอ
# 57508  57509    2021-04-26  ...    ไม่ทราบจังหวัด      ไม่ทราบอำเภอ
# 57509  57510    2021-04-26  ...    ไม่ทราบจังหวัด      ไม่ทราบอำเภอ
#
# [57510 rows x 11 columns]

# %%
Data_covid_M1_2020 = data_01[data_01['announce_date']<= '2020-01-31']
F1 = Data_covid_M1_2020.shape[0]
F1
# Out:
# 19

# %%
Data_covid_M2_2020 = data_01[data_01['announce_date']<= '2020-02-29']
F2 = Data_covid_M2_2020.shape[0]-Data_covid_M1_2020.shape[0]
F2
# Out:
# 23

# %%
Data_covid_M3_2020 = data_01[data_01['announce_date']<= '2020-03-31']
F3 = Data_covid_M3_2020.shape[0]-Data_covid_M2_2020.shape[0]
F3
# Out:
# 1609

# %%
Data_covid_M4_2020 = data_01[data_01['announce_date']<= '2020-04-30']
F4 = Data_covid_M4_2020.shape[0]-Data_covid_M3_2020.shape[0]
F4
# Out:
# 1303

# %%
Data_covid_M5_2020 = data_01[data_01['announce_date']<= '2020-05-31']
F5 = Data_covid_M5_2020.shape[0]-Data_covid_M4_2020.shape[0]
F5
# Out:
# 127

# %%
Data_covid_M6_2020 = data_01[data_01['announce_date']<= '2020-06-30']
F6 = Data_covid_M6_2020.shape[0]-Data_covid_M5_2020.shape[0]
F6
# Out:
# 90

# %%
Data_covid_M7_2020 = data_01[data_01['announce_date']<= '2020-07-31']
F7 = Data_covid_M7_2020.shape[0]-Data_covid_M6_2020.shape[0]
F7
# Out:
# 139

# %%
Data_covid_M8_2020 = data_01[data_01['announce_date']<= '2020-08-31']
F8 = Data_covid_M8_2020.shape[0]-Data_covid_M7_2020.shape[0]
F8
# Out:
# 102

# %%
Data_covid_M9_2020 = data_01[data_01['announce_date']<= '2020-09-30']
F9 = Data_covid_M9_2020.shape[0]-Data_covid_M8_2020.shape[0]
F9
# Out:
# 152

# %%
Data_covid_M10_2020 = data_01[data_01['announce_date']<= '2020-10-31']
F10 = Data_covid_M10_2020.shape[0]-Data_covid_M9_2020.shape[0]
F10
# Out:
# 216

# %%
Data_covid_M11_2020 = data_01[data_01['announce_date']<= '2020-11-30']
F11 = Data_covid_M11_2020.shape[0]-Data_covid_M10_2020.shape[0]
F11
# Out:
# 218

# %%
Data_covid_M12_2020 = data_01[data_01['announce_date']<= '2020-12-31']
F12 = Data_covid_M12_2020.shape[0]-Data_covid_M11_2020.shape[0]
F12
# Out:
# 2886

# %%
Data_covid_M1_2021 = data_01[data_01['announce_date']<= '2021-01-31']
F13 = Data_covid_M1_2021.shape[0]-Data_covid_M12_2020.shape[0]
F13
# Out:
# 11898

# %%
Data_covid_M2_2021 = data_01[data_01['announce_date']<= '2021-02-28']
F14 = Data_covid_M2_2021.shape[0]-Data_covid_M1_2021.shape[0]
F14
# Out:
# 7169

# %%
Data_covid_M3_2021 = data_01[data_01['announce_date']<= '2021-03-31']
F15 = Data_covid_M3_2021.shape[0]-Data_covid_M2_2021.shape[0]
F15
# Out:
# 2912

# %%
Data_covid_M4_2021 = data_01[data_01['announce_date']<= '2021-04-30']
F16 = Data_covid_M4_2021.shape[0]-Data_covid_M3_2021.shape[0]
F16
# Out:
# 28647

# %%
labels1 = ['Jan20','Feb20','Mar20','Apr20','Mar20','Jun20','Jul20','Aug20','Sep20','Oct20','Nov20','Dec20','Jan21','Feb21','Mar21','Apr21']

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.2.2'

# %%
import matplotlib.pyplot as plt
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels1, v1, width, label='before lunch',color = '#fc9700')
ax.bar(labels1, v2, width, bottom=v1, label='before midnight',color = '#19038a')

ax.set_ylabel('number of requests')
ax.set_title('ปริมาณคนเข้าใช้ Wongnai.com ในแต่ละวัน โดยคิดจาก 2 ช่วงเวลา')
ax.legend()

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3611 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3619 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3636 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3617 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3634 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# ## ข้อ 2 เปรียบเทียบวิธีการเดินทางของคนเป็นรายเดือนเทียบกับจำนวนผู้ป่วยในเดือนนั้นๆ

# %%
#ื กราฟวงกลมเปรียบเทียบวิธีการเดินทางของคนเป็นรายเดือนเทียบกับจำนวนผู้ป่วยในเดือนที่ 1 ปี 2020
import matplotlib.pyplot as plt
import numpy as np
mylabels1 = ['By land','Waterways','Rail','Air','The patient']
y1_2020 = np.array([T1_1.sum(),T1_2.sum(),T1_3.sum(),T1_4.sum(),F1])
explode = (0, 0, 0, 0,0) 
fig1, ax1 = plt.subplots()
ax1.pie(y1_2020, explode=explode, labels=mylabels1, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  
plt.show()

# %%
#ื กราฟวงกลมเปรียบเทียบวิธีการเดินทางของคนเป็นรายเดือนเทียบกับจำนวนผู้ป่วยในเดือนที่ 2 ปี 2020
import matplotlib.pyplot as plt
import numpy as np
mylabels1 = ['By land','Waterways','Rail','Air','The patient']
y2_2020 = np.array([T2_1.sum(),T2_2.sum(),T2_3.sum(),T2_4.sum(),F2])
explode = (0, 0, 0, 0,0) 
fig1, ax1 = plt.subplots()
ax1.pie(y2_2020, explode=explode, labels=mylabels1, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  
plt.show()

# %%
#ื กราฟวงกลมเปรียบเทียบวิธีการเดินทางของคนเป็นรายเดือนเทียบกับจำนวนผู้ป่วยในเดือนที่ 3  ปี 2020
import matplotlib.pyplot as plt
import numpy as np
mylabels1 = ['By land','Waterways','Rail','Air','The patient']
y3_2020 = np.array([T3_1.sum(),T3_2.sum(),T3_3.sum(),T3_4.sum(),F3])
explode = (0, 0, 0, 0,0) 
fig1, ax1 = plt.subplots()
ax1.pie(y3_2020, explode=explode, labels=mylabels1, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  
plt.show()

# %%
#ื กราฟวงกลมเปรียบเทียบวิธีการเดินทางของคนเป็นรายเดือนเทียบกับจำนวนผู้ป่วยในเดือนที่ 4  ปี 2020
import matplotlib.pyplot as plt
import numpy as np
mylabels1 = ['By land','Waterways','Rail','Air','The patient']
y4_2020 = np.array([T4_1.sum(),T4_2.sum(),T4_3.sum(),T4_4.sum(),F4])
explode = (0, 0, 0, 0,0) 
fig1, ax1 = plt.subplots()
ax1.pie(y4_2020, explode=explode, labels=mylabels1, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  
plt.show()

# %%
#ื กราฟวงกลมเปรียบเทียบวิธีการเดินทางของคนเป็นรายเดือนเทียบกับจำนวนผู้ป่วยในเดือนที่ 5  ปี 2020
import matplotlib.pyplot as plt
import numpy as np
mylabels1 = ['By land','Waterways','Rail','Air','The patient']
y5_2020 = np.array([T5_1.sum(),T5_2.sum(),T5_3.sum(),T5_4.sum(),F5])
explode = (0, 0, 0, 0,0) 
fig1, ax1 = plt.subplots()
ax1.pie(y5_2020, explode=explode, labels=mylabels1, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  
plt.show()

# %%
#ื กราฟวงกลมเปรียบเทียบวิธีการเดินทางของคนเป็นรายเดือนเทียบกับจำนวนผู้ป่วยในเดือนที่ 6  ปี 2020
import matplotlib.pyplot as plt
import numpy as np
mylabels1 = ['By land','Waterways','Rail','Air','The patient']
y6_2020 = np.array([T6_1.sum(),T6_2.sum(),T6_3.sum(),T6_4.sum(),F6])
explode = (0, 0, 0, 0,0) 
fig1, ax1 = plt.subplots()
ax1.pie(y6_2020, explode=explode, labels=mylabels1, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  
plt.show()

# %%
#ื กราฟวงกลมเปรียบเทียบวิธีการเดินทางของคนเป็นรายเดือนเทียบกับจำนวนผู้ป่วยในเดือนที่ 7  ปี 2020
import matplotlib.pyplot as plt
import numpy as np
mylabels1 = ['By land','Waterways','Rail','Air','The patient']
y7_2020 = np.array([T7_1.sum(),T7_2.sum(),T7_3.sum(),T7_4.sum(),F7])
explode = (0, 0, 0, 0,0) 
fig1, ax1 = plt.subplots()
ax1.pie(y7_2020, explode=explode, labels=mylabels1, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  
plt.show()

# %%
#ื กราฟวงกลมเปรียบเทียบจำนวนผู้ป่วยกับจำนวนคนเดินทางในเดือนที่ 5 ปี 2020
import matplotlib.pyplot as plt
import numpy as np
y5_2020_1 = np.array([M5_2020.sum(),F5])
mylabels3 = ['Traveler','The patient']
explode = (0, 0.2) 
fig1, ax1 = plt.subplots()
ax1.pie(y5_2020_1, explode=explode, labels=mylabels3, autopct='%1.1f%%', shadow = True, startangle=90)
ax1.axis('equal')  
plt.show()

# %%
#ื กราฟวงกลมเปรียบเทียบจำนวนผู้ป่วยกับจำนวนคนเดินทางในเดือนที่ 6 ปี 2020
import matplotlib.pyplot as plt
import numpy as np
y6_2020_1 = np.array([M6_2020.sum(),F6])
mylabels3 = ['Traveler','The patient']
explode = (0, 0.2) 
fig1, ax1 = plt.subplots()
ax1.pie(y6_2020_1, explode=explode, labels=mylabels3, autopct='%1.1f%%', shadow = True, startangle=90)
ax1.axis('equal')  
plt.show()

# %%
#ื กราฟวงกลมเปรียบเทียบจำนวนผู้ป่วยกับจำนวนคนเดินทางในเดือนที่ 7 ปี 2020
import matplotlib.pyplot as plt
import numpy as np
y7_2020_1 = np.array([M7_2020.sum(),F7])
mylabels3 = ['Traveler','The patient']
explode = (0, 0.2) 
fig1, ax1 = plt.subplots()
ax1.pie(y7_2020_1, explode=explode, labels=mylabels3, autopct='%1.1f%%', shadow = True, startangle=90)
ax1.axis('equal')  
plt.show()

# %%
#ื กราฟวงกลมเปรียบเทียบจำนวนผู้ป่วยกับจำนวนคนเดินทางในเดือนที่ 8 ปี 2020
import matplotlib.pyplot as plt
import numpy as np
y8_2020_1 = np.array([M8_2020.sum(),F8])
mylabels3 = ['Traveler','The patient']
explode = (0, 0.2) 
fig1, ax1 = plt.subplots()
ax1.pie(y8_2020_1, explode=explode, labels=mylabels3, autopct='%1.1f%%', shadow = True, startangle=90)
ax1.axis('equal')  
plt.show()

# %%
#ื กราฟวงกลมเปรียบเทียบจำนวนผู้ป่วยกับจำนวนคนเดินทางในเดือนที่ 9 ปี 2020
import matplotlib.pyplot as plt
import numpy as np
y9_2020_1 = np.array([M9_2020.sum(),F9])
mylabels3 = ['Traveler','The patient']
explode = (0, 0.2) 
fig1, ax1 = plt.subplots()
ax1.pie(y9_2020_1, explode=explode, labels=mylabels3, autopct='%1.1f%%', shadow = True, startangle=90)
ax1.axis('equal')  
plt.show()

# %%
#ื กราฟวงกลมเปรียบเทียบจำนวนผู้ป่วยกับจำนวนคนเดินทางในเดือนที่ 10 ปี 2020
import matplotlib.pyplot as plt
import numpy as np
y10_2020_1 = np.array([M10_2020.sum(),F10])
mylabels3 = ['Traveler','The patient']
explode = (0, 0.2) 
fig1, ax1 = plt.subplots()
ax1.pie(y10_2020_1, explode=explode, labels=mylabels3, autopct='%1.1f%%', shadow = True, startangle=90)
ax1.axis('equal')  
plt.show()

# %%
#ื กราฟวงกลมเปรียบเทียบจำนวนผู้ป่วยกับจำนวนคนเดินทางในเดือนที่ 11 ปี 2020
import matplotlib.pyplot as plt
import numpy as np
y11_2020_1 = np.array([M11_2020.sum(),F11])
mylabels3 = ['Traveler','The patient']
explode = (0, 0.2) 
fig1, ax1 = plt.subplots()
ax1.pie(y11_2020_1, explode=explode, labels=mylabels3, autopct='%1.1f%%', shadow = True, startangle=90)
ax1.axis('equal')  
plt.show()

# %%
#ื กราฟวงกลมเปรียบเทียบจำนวนผู้ป่วยกับจำนวนคนเดินทางในเดือนที่ 12 ปี 2020
import matplotlib.pyplot as plt
import numpy as np
y12_2020_1 = np.array([M12_2020.sum(),F12])
mylabels3 = ['Traveler','The patient']
explode = (0, 0.2) 
fig1, ax1 = plt.subplots()
ax1.pie(y12_2020_1, explode=explode, labels=mylabels3, autopct='%1.1f%%', shadow = True, startangle=90)
ax1.axis('equal')  
plt.show()

# %%
#ื กราฟวงกลมเปรียบเทียบจำนวนผู้ป่วยกับจำนวนคนเดินทางในเดือนที่ 1 ปี 2021
import matplotlib.pyplot as plt
import numpy as np
y1_2021_1 = np.array([M1_2021.sum(),F13])
mylabels3 = ['Traveler','The patient']
explode = (0, 0.2) 
fig1, ax1 = plt.subplots()
ax1.pie(y1_2021_1, explode=explode, labels=mylabels3, autopct='%1.1f%%', shadow = True, startangle=90)
ax1.axis('equal')  
plt.show()

# %%
#ื กราฟวงกลมเปรียบเทียบจำนวนผู้ป่วยกับจำนวนคนเดินทางในเดือนที่ 2 ปี 2021
import matplotlib.pyplot as plt
import numpy as np
y2_2021_1 = np.array([M2_2021.sum(),F14])
mylabels3 = ['Traveler','The patient']
explode = (0, 0.2) 
fig1, ax1 = plt.subplots()
ax1.pie(y2_2021_1, explode=explode, labels=mylabels3, autopct='%1.1f%%', shadow = True, startangle=90)
ax1.axis('equal')  
plt.show()

# %%
#ื กราฟวงกลมเปรียบเทียบจำนวนผู้ป่วยกับจำนวนคนเดินทางในเดือนที่ 3 ปี 2021
import matplotlib.pyplot as plt
import numpy as np
y3_2021_1 = np.array([M3_2021.sum(),F15])
mylabels3 = ['Traveler','The patient']
explode = (0, 0.2) 
fig1, ax1 = plt.subplots()
ax1.pie(y3_2021_1, explode=explode, labels=mylabels3, autopct='%1.1f%%', shadow = True, startangle=90)
ax1.axis('equal')  
plt.show()

# %%
#ื กราฟวงกลมเปรียบเทียบจำนวนผู้ป่วยกับจำนวนคนเดินทางในเดือนที่ 4 ปี 2021
import matplotlib.pyplot as plt
import numpy as np
y4_2021_1 = np.array([M4_2021.sum(),F16])
mylabels3 = ['Traveler','The patient']
explode = (0, 0.2) 
fig1, ax1 = plt.subplots()
ax1.pie(y4_2021_1, explode=explode, labels=mylabels3, autopct='%1.1f%%', shadow = True, startangle=90)
ax1.axis('equal')  
plt.show()
